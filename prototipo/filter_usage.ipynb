# %%
import sys  
import os
sys.path.insert(0, os.path.join('..', '..', 'trabalho_PI'))

import efeitos
import matplotlib.pyplot as plt


nome_file = os.path.join('..', 'imagens', 'Limes.jpg')
imagem_blur = efeitos.blur(nome_file)
plt.imshow(imagem_blur)

# %%
imagem_sobel = efeitos.sobel(nome_file)
plt.imshow(imagem_sobel, cmap="gray")

# %%
imagem_unsharp = efeitos.unsharp(nome_file)
plt.imshow(imagem_unsharp)

# %%
imagem_sharpening = efeitos.sharpening(nome_file)
plt.imshow(imagem_sharpening)
